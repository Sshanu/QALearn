# %%
import numpy as np
import re


# function which takes text file as input and returns index_list and corresponding sections
with open("qalearn/media/txt/UG-Manual.txt", 'r') as f:
    test_str = f.read()
flag = 0
# retrieving indexes
test_str = test_str.lower()
regex = r"(Contents)|(contents)"

match = re.search(regex, test_str)
start = match.end()

test_str = test_str[start:]

regex = r"[.…]{2,}\s+\d+"

test_str = re.sub(regex, "", test_str)

# %%
regex = r")[\d.]*)\s+([^}].+)"
contents = []
ids = []
parents = []
count = 1
last = None
content_flag = 1
final_str = test_str
while(content_flag):
    match = re.search("\s*((" + str(count) +"|"+ str(count+1) + "|"+ str(count+2)+ regex, final_str)
    id = match.group(1)
    if(id in ids):
        content_flag = 0
        break
    count = max(count, int(match.group(2)))
    contents.append(match.group(3))
    parents.append(match.group(2))
    ids.append(id)
    final_str = final_str[match.end():]
    print(count, parents[-1], ids[-1], contents[-1])
    last = match.end()
# Out:
# 1 1 1 introduction
# 2 2 2 programmes of study
# 2 2 2.1 programmes for new students
# 2 2 2.1.1 admission through jee
# 2 2 2.1.2 admission through jam
# 2 2 2.2 options for already enrolled students
# 2 2 2.2.1 branch change
# 2 2 2.2.2 double-major
# 2 2 2.2.3 dual-degree
# 2 2 2.2.4 minors
# 3 3 3 admission procedure and rules
# 3 3 3.1 for new students
# 3 3 3.1.1 b tech and bs programmes
# 3 3 3.1.2 msc and mspd programmes
# 3 3 3.2 non-degree students
# 3 3 3.3 validity of admission and its cancellation
# 4 4 4 academic session
# 4 4 4.1 dates
# 4 4 4.2 duration
# 4 4 4.3 academic calendar
# 5 5 5 curriculum
# 5 5 5.1 b tech and bs programmes
# 5 5 5.1.1 double major
# 5 5 5.2 bachelors-masters dual degree programme
# 5 5 5.3 msc programme
# 5 5 5.4 mspd dual degree programme
# 5 5 5.5 list of courses
# 6 6 6 registration
# 6 6 6.1 academic registration
# 6 6 6.1.1 pre-registration
# 6 6 6.1.2 final registration
# 6 6 6.1.3 add-drop of courses
# 6 6 6.1.4 cancellation of registration in a course
# 6 6 6.1.5 academic load in regular semesters
# 6 6 6.1.5.1 exceptions to regular rules regarding academic load
# 6 6 6.1.6 academic load in summer term
# 6 6 6.1.7 cancellation of registration
# 6 6 6.2 administrative registration
# 6 6 6.3 late registration
# 7 7 7 teaching and evaluation
# 7 7 7.1 teaching
# 7 7 7.1.1 medium of instruction
# 7 7 7.1.2 offering a new course
# 7 7 7.1.3 courses offerings for a  given semester
# 7 7 7.1.4 duration of courses
# 7 7 7.1.5 conduct of courses
# 7 7 7.1.6 attendance in class
# 7 7 7.1.7 work-week and class timings
# 7 7 7.2 evaluation and performance feedback
# 7 7 7.2.1 examinations
# 7 7 7.2.2 quizzes
# 7 7 7.2.3 make-up examination
# 7 7 7.2.4 results of examinations and quizzes
# 7 7 7.2.5 letter grades and weights
# 7 7 7.2.6 semester performance index
# 7 7 7.2.7 cumulative performance index
# 7 7 7.2.8 declaration of the final result
# 7 7 7.2.9 withholding of grades
# 7 7 7.2.10 change of an already awarded grade
# 8 8 8 academic requirements and degree eligibility
# 8 8 8.1 minimum and maximum duration
# 8 8 8.2 minimum academic requirements
# 8 8 8.3 graduation
# 8 8 8.3.1 graduation with distinction
# 8 8 8.4 award of degrees
# 8 8 8.5 withdrawal of the degree
# 9 9 9 inadequate academic performance
# 9 9 9.1 mechanism to address inadequate academic performance
# 9 9 9.2 warning
# 9 9 9.3 academic probation
# 9 9 9.4 programme termination
# 9 9 9.5 appeal against termination
# 10 10 10 rules governing change or addition to the programme
# 10 10 10.1 branch change
# 10 10 10.1.1 eligibility
# 10 10 10.1.2 application process
# 10 10 10.1.3 academic road-map
# 10 10 10.2 bachelors-masters dual degree programme
# 10 10 10.2.1 eligibility
# 10 10 10.2.2 application process
# 10 10 10.2.3 academic road-map
# 10 10 10.2.4 withdrawal from the bachelors-masters dual degree programme
# 10 10 10.2.5 termination of pg part of the bachelors-masters dual degree programme
# 10 10 10.3 double major
# 10 10 10.3.1 eligibility
# 10 10 10.3.2 application process
# 10 10 10.3.3 academic road-map
# 10 10 10.3.4 withdrawal from the double major programme
# 10 10 10.3.5 termination of the double major programme
# 10 10 10.4 minor
# 10 10 10.4.1 eligibility
# 10 10 10.4.2 application process
# 10 10 10.4.3 retrospective minor
# 10 10 10.4.4 academic road-map
# 10 10 10.4.5 withdrawal from a minor
# 10 10 10.5 mspd dual degree programme
# 10 10 10.5.1 eligibility
# 10 10 10.5.2 application process
# 10 10 10.5.3 academic roadmap
# 10 10 10.5.4 withdrawal from the m.sc.-ph.d. dual degree programme
# 10 10 10.6 calculation of seat availability
# 10 10 10.6.1 branch change
# 10 10 10.6.2 bachelors-masters dual degree
# 10 10 10.6.3 double major
# 10 10 10.6.4 minor
# 11 11 11 leave of absence
# 11 11 11.1 mid-semester recess and vacation
# 11 11 11.2 short leave
# 11 11 11.3 temporary withdrawal/ semester leave
# 11 11 11.4 penalty for unsanctioned or excessive leaves
# 11 11 11.5 permission to proceed to other institutions
# 11 11 11.5.1 eligibility
# 11 11 11.5.2 application procedure
# 11 11 11.5.3 transfer of credits and waiver in-lieu thereof
# 12 12 12 scholarships, awards and medals
# 12 12 12.1 scholarships
# 12 12 12.2 withdrawal of scholarships
# 12 12 12.3 awards and medals
# 13 13 13 conduct and discipline
# 13 13 13.1 code of conduct
# 13 13 13.2 disciplinary actions and related matter
# 14 14 14 a quick guide for students
# 16 16 16 waiver and amendments
# 16 16 16.1 waiver
# 16 16 16.2 amendments

# %%
id2ids = dict((w, i) for i, w in enumerate(ids))

def find_section(final_str, section_id, section_title):
    try:
#         regex = "(" + section_id + "|" + str(int(section_id)+1)+ ")"  + "\s*" +section_title 
        regex = "(" + section_id + ")"  + "\s*" +section_title 
        match  = re.search(regex, final_str)
        end = match.start()
        print(1)
        
    except AttributeError:
        
        if(re.search("\.", section_id) == None):
            regex = "(" + section_title  + ")"  + "\s*" 
        else:
            regex = "(" + section_id + ")"  + "\s*"
            
        try:
            match  = re.search(regex, final_str)
            end = match.start()
            print(2)
            
        except AttributeError:
            print("error")
            return -1
        
    print(match)
    return end

for i,c in enumerate(contents):
    contents[i]  = " ".join(c.split())

# Graph Class
class Graph:

    def __init__(self,v):
        self.graph = [list() for i in range(v)]

    def addEdge(self,u,v):
        self.graph[u].append(v)

    def DFSUtil(self, v, visited,res,ans):
        visited[v]= True
        res.append(contents[v])
        #print(v)
        count=0
        for i in self.graph[v]:
            count+=1
            if visited[i] == False:
                self.DFSUtil(i, visited,res,ans)
        if count==0:
            final_res=[' '.join(res),res[-1],ind2id[v]]
            #print(final_res)
            ans.append(final_res)
        res.pop()    

    def DFS(self):
        res=[]
        ans=[]
        V = len(self.graph) 
        visited =V*[False]
        for i in range(V):
            if visited[i] == False:
                self.DFSUtil(i, visited,res,ans)
                res=[]

        return ans

id2ind = dict([(w,i) for i,w in enumerate(ids)])
ind2id = dict([(i,w) for i,w in enumerate(ids)])
nodes=[]
for it in contents:
    nodes.append(it.split())
parents=[int(i) for i in parents]
g=Graph(len(ids))
for i in ids:
    if i not in [str(i) for i in set(parents)]:
        g.addEdge(id2ind['.'.join(i.split('.')[:-1])],id2ind[i])

index_list = g.DFS()

# print(index_list)
# final_str = test_str[last:]    

start = find_section(final_str, index_list[0][2], index_list[0][1])

sections = []
for i in range(len(index_list)-1):

    
    end = find_section(final_str, index_list[i+1][2], index_list[i+1][1])
    if(end>start):
        sections.append(final_str[start:end])
        
        for j in range(id2ids[index_list[i+1][2]]):
            regex = ids[j] + "\s+" + contents[j]
            sections[-1] = re.sub(regex, "", sections[-1])
            
        final_str = final_str[end:]
        start = 0
    else:  
        flag = 1
        print("error", i, start, end)
        
    print(start, end)
sections.append(final_str[start:])
# Out:
# 1
# <_sre.SRE_Match object; span=(23, 41), match='1 \n \n\nintroduction'>
# 1
# <_sre.SRE_Match object; span=(3494, 3521), match='2.1.1 admission through jee'>
# 0 3494
# 1
# <_sre.SRE_Match object; span=(715, 742), match='2.1.2 admission through jam'>
# 0 715
# 1
# <_sre.SRE_Match object; span=(645, 664), match='2.2.1 branch change'>
# 0 645
# 2
# <_sre.SRE_Match object; span=(354, 360), match='2.2.2 '>
# 0 354
# 1
# <_sre.SRE_Match object; span=(356, 373), match='2.2.3 dual-degree'>
# 0 356
# 1
# <_sre.SRE_Match object; span=(1054, 1066), match='2.2.4 minors'>
# 0 1054
# 1
# <_sre.SRE_Match object; span=(539, 569), match='3.1.1 b tech and bs programmes'>
# 0 539
# 2
# <_sre.SRE_Match object; span=(2392, 2398), match='3.1.2 '>
# 0 2392
# 1
# <_sre.SRE_Match object; span=(1326, 1349), match='3.2 non-degree students'>
# 0 1326
# 1
# <_sre.SRE_Match object; span=(1543, 1589), match='3.3 validity of admission and its cancellation'>
# 0 1543
# 1
# <_sre.SRE_Match object; span=(1065, 1074), match='4.1 dates'>
# 0 1065
# 1
# <_sre.SRE_Match object; span=(388, 400), match='4.2 duration'>
# 0 388
# 1
# <_sre.SRE_Match object; span=(703, 724), match='4.3 academic calendar'>
# 0 703
# 1
# <_sre.SRE_Match object; span=(1854, 1874), match='5.1.1   double major'>
# 0 1854
# 1
# <_sre.SRE_Match object; span=(722, 767), match='5.2   bachelors-masters dual degree programme'>
# 0 722
# 1
# <_sre.SRE_Match object; span=(692, 711), match='5.3   msc programme'>
# 0 692
# 1
# <_sre.SRE_Match object; span=(549, 582), match='5.4    mspd dual degree programme'>
# 0 549
# 1
# <_sre.SRE_Match object; span=(657, 679), match='5.5    list of courses'>
# 0 657
# 1
# <_sre.SRE_Match object; span=(1845, 1867), match='6.1.1 pre-registration'>
# 0 1845
# 1
# <_sre.SRE_Match object; span=(1753, 1777), match='6.1.2 final registration'>
# 0 1753
# 1
# <_sre.SRE_Match object; span=(821, 846), match='6.1.3 add-drop of courses'>
# 0 821
# 1
# <_sre.SRE_Match object; span=(1204, 1250), match='6.1.4 cancellation of registration in a course'>
# 0 1204
# 1
# <_sre.SRE_Match object; span=(1880, 1939), match='6.1.5.1 exceptions to regular rules regarding aca>
# 0 1880
# 1
# <_sre.SRE_Match object; span=(2103, 2137), match='6.1.6 academic load in summer term'>
# 0 2103
# 1
# <_sre.SRE_Match object; span=(966, 1000), match='6.1.7 cancellation of registration'>
# 0 966
# 1
# <_sre.SRE_Match object; span=(432, 463), match='6.2 administrative registration'>
# 0 432
# 1
# <_sre.SRE_Match object; span=(159, 180), match='6.3 late registration'>
# 0 159
# 1
# <_sre.SRE_Match object; span=(720, 747), match='7.1.1 medium of instruction'>
# 0 720
# 1
# <_sre.SRE_Match object; span=(382, 409), match='7.1.2 offering a new course'>
# 0 382
# 1
# <_sre.SRE_Match object; span=(1012, 1056), match='7.1.3 courses offerings for a given semester'>
# 0 1012
# 1
# <_sre.SRE_Match object; span=(488, 513), match='7.1.4 duration of courses'>
# 0 488
# 1
# <_sre.SRE_Match object; span=(294, 318), match='7.1.5 conduct of courses'>
# 0 294
# 1
# <_sre.SRE_Match object; span=(392, 417), match='7.1.6 attendance in class'>
# 0 392
# 1
# <_sre.SRE_Match object; span=(843, 876), match='7.1.7 work-week and class timings'>
# 0 843
# 1
# <_sre.SRE_Match object; span=(1507, 1525), match='7.2.1 examinations'>
# 0 1507
# 2
# <_sre.SRE_Match object; span=(412, 418), match='7.2.2 '>
# 0 412
# 1
# <_sre.SRE_Match object; span=(524, 549), match='7.2.3 make-up examination'>
# 0 524
# 1
# <_sre.SRE_Match object; span=(958, 999), match='7.2.4 results of examinations and quizzes'>
# 0 958
# 2
# <_sre.SRE_Match object; span=(864, 870), match='7.2.5 '>
# 0 864
# 1
# <_sre.SRE_Match object; span=(2610, 2642), match='7.2.6 semester performance index'>
# 0 2610
# 1
# <_sre.SRE_Match object; span=(763, 797), match='7.2.7 cumulative performance index'>
# 0 763
# 1
# <_sre.SRE_Match object; span=(550, 587), match='7.2.8 declaration of the final result'>
# 0 550
# 1
# <_sre.SRE_Match object; span=(393, 420), match='7.2.9 withholding of grades'>
# 0 393
# 1
# <_sre.SRE_Match object; span=(246, 287), match='7.2.10 change of an already awarded grade'>
# 0 246
# 1
# <_sre.SRE_Match object; span=(545, 577), match='8.1 minimum and maximum duration'>
# 0 545
# 2
# <_sre.SRE_Match object; span=(1083, 1087), match='8.2 '>
# 0 1083
# 1
# <_sre.SRE_Match object; span=(1233, 1266), match='8.3.1 graduation with distinction'>
# 0 1233
# 1
# <_sre.SRE_Match object; span=(199, 219), match='8.4 award of degrees'>
# 0 199
# 1
# <_sre.SRE_Match object; span=(302, 330), match='8.5 withdrawal of the degree'>
# 0 302
# 2
# <_sre.SRE_Match object; span=(425, 429), match='9.1 '>
# 0 425
# 1
# <_sre.SRE_Match object; span=(1378, 1389), match='9.2 warning'>
# 0 1378
# 1
# <_sre.SRE_Match object; span=(578, 600), match='9.3 academic probation'>
# 0 578
# 1
# <_sre.SRE_Match object; span=(770, 795), match='9.4 programme termination'>
# 0 770
# 1
# <_sre.SRE_Match object; span=(1078, 1108), match='9.5 appeal against termination'>
# 0 1078
# 1
# <_sre.SRE_Match object; span=(1208, 1226), match='10.1.1 eligibility'>
# 0 1208
# 1
# <_sre.SRE_Match object; span=(573, 599), match='10.1.2 application process'>
# 0 573
# 1
# <_sre.SRE_Match object; span=(541, 565), match='10.1.3 academic road-map'>
# 0 541
# 1
# <_sre.SRE_Match object; span=(1662, 1680), match='10.2.1 eligibility'>
# 0 1662
# 1
# <_sre.SRE_Match object; span=(1263, 1289), match='10.2.2 application process'>
# 0 1263
# 1
# <_sre.SRE_Match object; span=(1061, 1085), match='10.2.3 academic road-map'>
# 0 1061
# 1
# <_sre.SRE_Match object; span=(1955, 2021), match='10.2.4 withdrawal from the bachelors-masters dual>
# 0 1955
# 1
# <_sre.SRE_Match object; span=(1043, 1119), match='10.2.5 termination of pg part of the bachelors-ma>
# 0 1043
# 1
# <_sre.SRE_Match object; span=(902, 920), match='10.3.1 eligibility'>
# 0 902
# 1
# <_sre.SRE_Match object; span=(962, 988), match='10.3.2 application process'>
# 0 962
# 1
# <_sre.SRE_Match object; span=(898, 922), match='10.3.3 academic road-map'>
# 0 898
# 1
# <_sre.SRE_Match object; span=(884, 933), match='10.3.4 withdrawal from the double major programme>
# 0 884
# 1
# <_sre.SRE_Match object; span=(777, 825), match='10.3.5 termination of the double major programme'>
# 0 777
# 1
# <_sre.SRE_Match object; span=(956, 974), match='10.4.1 eligibility'>
# 0 956
# 1
# <_sre.SRE_Match object; span=(641, 667), match='10.4.2 application process'>
# 0 641
# 1
# <_sre.SRE_Match object; span=(1114, 1140), match='10.4.3 retrospective minor'>
# 0 1114
# 1
# <_sre.SRE_Match object; span=(723, 747), match='10.4.4 academic road-map'>
# 0 723
# 1
# <_sre.SRE_Match object; span=(682, 712), match='10.4.5 withdrawal from a minor'>
# 0 682
# 1
# <_sre.SRE_Match object; span=(366, 384), match='10.5.1 eligibility'>
# 0 366
# 1
# <_sre.SRE_Match object; span=(313, 339), match='10.5.2 application process'>
# 0 313
# 1
# <_sre.SRE_Match object; span=(433, 456), match='10.5.3 academic roadmap'>
# 0 433
# 2
# <_sre.SRE_Match object; span=(951, 958), match='10.5.4 '>
# 0 951
# 1
# <_sre.SRE_Match object; span=(313, 333), match='10.6.1 branch change'>
# 0 313
# 1
# <_sre.SRE_Match object; span=(2179, 2215), match='10.6.2 bachelors-masters dual degree'>
# 0 2179
# 1
# <_sre.SRE_Match object; span=(973, 992), match='10.6.3 double major'>
# 0 973
# 1
# <_sre.SRE_Match object; span=(608, 620), match='10.6.4 minor'>
# 0 608
# 1
# <_sre.SRE_Match object; span=(895, 932), match='11.1 mid-semester recess and vacation'>
# 0 895
# 1
# <_sre.SRE_Match object; span=(229, 245), match='11.2 short leave'>
# 0 229
# 1
# <_sre.SRE_Match object; span=(734, 775), match='11.3 temporary withdrawal/ semester leave'>
# 0 734
# 2
# <_sre.SRE_Match object; span=(1490, 1495), match='11.4 '>
# 0 1490
# 1
# <_sre.SRE_Match object; span=(1912, 1930), match='11.5.1 eligibility'>
# 0 1912
# 1
# <_sre.SRE_Match object; span=(96, 124), match='11.5.2 application procedure'>
# 0 96
# 1
# <_sre.SRE_Match object; span=(895, 948), match='11.5.3 transfer of credits and waiver in-lieu the>
# 0 895
# 1
# <_sre.SRE_Match object; span=(1916, 1933), match='12.1 scholarships'>
# 0 1916
# 2
# <_sre.SRE_Match object; span=(673, 678), match='12.2 '>
# 0 673
# 1
# <_sre.SRE_Match object; span=(457, 479), match='12.3 awards and medals'>
# 0 457
# 1
# <_sre.SRE_Match object; span=(588, 608), match='13.1 code of conduct'>
# 0 588
# 2
# <_sre.SRE_Match object; span=(1691, 1696), match='13.2 '>
# 0 1691
# 1
# <_sre.SRE_Match object; span=(2615, 2648), match='14 \n \n\na quick guide for students'>
# 0 2615
# 1
# <_sre.SRE_Match object; span=(6369, 6380), match='16.1 waiver'>
# 0 6369
# 1
# <_sre.SRE_Match object; span=(250, 265), match='16.2 amendments'>
# 0 250

# %%
import sys
sys.path.insert(0, r'pdfminer/tools/')
import os

# %%
os.system("pdfminer/tools/dumppdf.py -T DeepLearning_Bible.pdf > Uug.txt")
# Out:
# 0

# %%
os.system("mupdf/mutool show UG-Manual.pdf outline")
# Out:
# 32512

# %%
regex = r"(Contents)|(contents)"

match = re.search(regex, test_str)
start = match.end()

contents_str = test_str[start:]

# %%
regex = r"((\s{2,})|)((\d{1,2})[\d.]*)\s+([^}].+)"
matches = re.finditer(regex, contents_str)
for matchNum, match in enumerate(matches):
    print(match.group(3), match.group(4))
# Out:
# 1 1
# 2 2
# 2.1 2
# 2.1.1 2
# 2.1.2 2
# 2.2 2
# 2.2.1 2
# 2.2.2 2
# 2.2.3 2
# 2.2.4 2
# 3 3
# 3.1 3
# 3.1.1 3
# 3.1.2 3
# 3.2 3
# 3.3 3
# 4 4
# 4.1 4
# 4.2 4
# 4.3 4
# 5 5
# 5.1 5
# 5.1.1 5
# 5.2 5
# 5.3 5
# 5.4 5
# 5.5 5
# 6 6
# 6.1 6
# 6.1.1 6
# 6.1.2 6
# 6.1.3 6
# 6.1.4 6
# 6.1.5 6
# 6.1.5.1 6
# 6.1.6 6
# 6.1.7 6
# 6.2 6
# 6.3 6
# 7 7
# 7.1 7
# 7.1.1 7
# 7.1.2 7
# 7.1.3 7
# 7.1.4 7
# 7.1.5 7
# 7.1.6 7
# 7.1.7 7
# 7.2 7
# 7.2.1 7
# 7.2.2 7
# 7.2.3 7
# 7.2.4 7
# 2 2
# 7.2.5 7
# 7.2.6 7
# 7.2.7 7
# 7.2.8 7
# 7.2.9 7
# 7.2.10 7
# 8 8
# 8.1 8
# 8.2 8
# 8.3 8
# 8.3.1 8
# 8.4 8
# 8.5 8
# 9 9
# 9.1 9
# 9.2 9
# 9.3 9
# 9.4 9
# 9.5 9
# 10 10
# 10.1 10
# 10.1.1 10
# 10.1.2 10
# 10.1.3 10
# 10.2 10
# 10.2.1 10
# 10.2.2 10
# 10.2.3 10
# 10.2.4 10
# 10.2.5 10
# 10.3 10
# 10.3.1 10
# 10.3.2 10
# 10.3.3 10
# 10.3.4 10
# 10.3.5 10
# 10.4 10
# 10.4.1 10
# 10.4.2 10
# 10.4.3 10
# 10.4.4 10
# 10.4.5 10
# 10.5 10
# 10.5.1 10
# 10.5.2 10
# 10.5.3 10
# 10.5.4 10
# 10.6 10
# 10.6.1 10
# 10.6.2 10
# 10.6.3 10
# 10.6.4 10
# 11 11
# 11.1 11
# 11.2 11
# 3 3
# 11.3 11
# 11.4 11
# 11.5 11
# 11.5.1 11
# 11.5.2 11
# 11.5.3 11
# 12 12
# 12.1 12
# 12.2 12
# 12.3 12
# 13 13
# 13.1 13
# 13.2 13
# 14 14
# 16 16
# 16.1 16
# 16.2 16
# 4 4
# 1 1
# 5 5
# 2 2
# 2.1 2
# 2.1.1 2
# 2.1.2 2
# 2.2 2
# 2.1 2
# 10. 10
# 2.2.1 2
# 2.2.2 2
# 2.2.3 2
# 6 6
# 2.2.4 2
# 7 7
# 3 3
# 3.1 3
# 3.1.1 3
# 3.1.2 3
# 8 8
# 3.2 3
# 3.3 3
# 9 9
# 4 4
# 4.1 4
# 4.2 4
# 4.3 4
# 10 10
# 5 5
# 5.1 5
# 5.1.1 5
# 5.2 5
# 5.3 5
# 11 11
# 5.4 5
# 5.5 5
# 12 12
# 6 6
# 6.1 6
# 6.1.1 6
# 6.1.2 6
# 13 13
# 6.1.3 6
# 44 44
# 6.1.4 6
# 6.1.5 6
# 30 30
# 65 65
# 6.1.5.1 6
# 30 30
# 65 65
# 100 10
# 14 14
# 8.5 8
# 70 70
# 6.1.6 6
# 25 25
# 6.1.7 6
# 20 20
# 10. 10
# 6.2 6
# 6.3 6
# 15 15
# 7 7
# 7.1 7
# 7.1.1 7
# 7.1.2 7
# 7.1.3 7
# 7.1.4 7
# 40 40
# 7.1.5 7
# 7.1.6 7
# 20 20
# 16 16
# 30 30
# 7.1.7 7
# 50 50
# 75 75
# 40 40
# 7.2 7
# 7.2.1 7
# 7.2.2 7
# 7.2.3 7
# 7.2.4 7
# 72 72
# 51 51
# 17 17
# 14 14
# 7.2.5 7
# 10 10
# 8 8
# 4 4
# 0 0
# 7.2.6 7
# 2 2
# 18 18
# 7.2.7 7
# 7.2.8 7
# 7.2.9 7
# 7.2.10 7
# 19 19
# 8 8
# 8.1 8
# 7 7
# 9 9
# 8 8
# 12 12
# 15 15
# 8.2 8
# 6.5 6
# 6.0 6
# 5.0. 5
# 1 1
# 8.3 8
# 8.1 8
# 8.3.1 8
# 8.5 8
# 20 20
# 8.4 8
# 8.3 8
# 8.5 8
# 21 21
# 9 9
# 9.1 9
# 9.2 9
# 2010 20
# 2012 20
# 2013 20
# 4.5 4
# 4.5 4
# 30 30
# 30 30
# 5.5 5
# 5.5 5
# 9.3 9
# 2010 20
# 2012 20
# 4.5 4
# 35 35
# 22 22
# 5.5 5
# 2013 20
# 30 30
# 30 30
# 30 30
# 30 30
# 9.4 9
# 2010 20
# 2012 20
# 2013 20
# 4.5 4
# 30 30
# 5.5 5
# 9.5 9
# 23 23
# 10 10
# 10.1 10
# 10.1.1 10
# 10.1.2 10
# 10.1.3 10
# 10.2 10
# 24 24
# 10.2.1 10
# 6.0 6
# 5.0 5
# 36 36
# 2011 20
# 10.6.2. 10
# 10.2.2 10
# 10.2.3 10
# 6.1.5 6
# 36 36
# 25 25
# 25 25
# 10.2.4 10
# 10.2.5 10
# 40 40
# 10.3 10
# 10.3.1 10
# 7.0 7
# 10.6.3. 10
# 10.3.2 10
# 10.3.3 10
# 26 26
# 36 36
# 25 25
# 10.3.4 10
# 10.3.5 10
# 12 12
# 12 12
# 10.4. 10
# 10.4.1 10
# 10.6.4. 10
# 10.4.2 10
# 27 27
# 10.4.3 10
# 10.4.4 10
# 36 36
# 10.4.5 10
# 10.5 10
# 10.5.1 10
# 7.0 7
# 10.5.2 10
# 10.5.3 10
# 28 28
# 6.0. 6
# 10.5.4 10
# 10.6 10
# 10.6.1 10
# 10.0 10
# 10.0 10
# 10.6.2 10
# 10 10
# 20 20
# 10 10
# 10 10
# 10 10
# 05 05
# 10.6.3 10
# 15 15
# 08 08
# 20 20
# 6 6
# 05 05
# 10 10
# 10.6.4 10
# 10 10
# 30 30
# 11 11
# 11.1 11
# 11.2 11
# 11.3 11
# 11.4 11
# 20 20
# 30 30
# 31 31
# 11.5 11
# 11.5.1 11
# 200 20
# 7.0 7
# 11.5.2 11
# 11.5.3. 11
# 11.5.3 11
# 100 10
# 32 32
# 12 12
# 12.1 12
# 12.2 12
# 12.3 12
# 33 33
# 13 13
# 13.1 13
# 13.2 13
# 34 34
# 35 35
# 14 14
# 35 35
# 25 25
# 1 1
# 2 2
# 3 3
# 4 4
# 7.0 7
# 7.0 7
# 36 36
# 5 5
# 6 6
# 6.0. 6
# 7 7
# 8 8
# 9 9
# 10 10
# 10 10
# 37 37
# 16 16
# 16.1 16
# 16.2 16
# 38 38

# %%
matches.start()
# Out:
# 18819

# %%
# retrieving indexes
regex = r"((\d{1,2})[\d.]*) ([^}].+)"
matches = re.finditer(regex, test_str)
contents = []
ids = []
parents = []
count = 0
last = None
for matchNum, match in enumerate(matches):
    matchNum = matchNum + 1

    id = match.group(1)
    if(id in ids):
        break

    count = max(count, int(match.group(2)))
    contents.append(match.group(3))
    parents.append(match.group(2))
    ids.append(id)
    last = match.end(3)
