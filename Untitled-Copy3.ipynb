# %%
import numpy as np
import re


# function which takes text file as input and returns index_list and corresponding sections
with open("qalearn/media/txt/ICC-Men-s-T20I-Playing-Conditions-2017-Code-FINAL-051017.txt", 'r') as f:
    test_str = f.read()
flag = 0
# retrieving indexes
test_str = test_str.lower()
regex = r"(Contents)|(contents)"

match = re.search(regex, test_str)
start = match.end()

test_str = test_str[start:]

regex = r"[.…]{2,}\s+\d+"

test_str = re.sub(regex, "", test_str)

# %%
regex = r")[\d.]*)\s+([^}].+)"
contents = []
ids = []
parents = []
count = 1
content_flag = 1
final_str = test_str
while(content_flag):
    try:
        match = re.search("\s*((" + str(count) +"|"+ str(count+1) + "|"+ str(count+2)+ regex, final_str[:200])
        id = match.group(1)
        if(id in ids):
            content_flag = 0
            break
        count = max(count, int(match.group(2)))
        contents.append(match.group(3))
        parents.append(match.group(2))
        ids.append(id)
        final_str = final_str[match.end():]
        print(count, parents[-1], ids[-1], contents[-1])
    except:
        break
# Out:
# 1 1 1 the umpires
# 2 2 2 the scorers
# 3 3 3 the ball
# 4 4 4 the bat
# 5 5 5 the pitch
# 6 6 6 the creases
# 7 7 7 the wickets
# 8 8 8 preparation and maintenance of the playing area
# 9 9 9 10  covering the pitch
# 11 11 11 intervals
# 12 12 12 start of play; cessation of play
# 13 13 13 innings
# 14 14 14 the follow-on
# 15 15 15 declaration and forfeiture
# 16 16 16 the result
# 17 17 17 the over
# 18 18 18 scoring runs
# 19 19 19 boundaries
# 20 20 20 dead ball
# 21 21 21 no ball
# 22 22 22 wide ball
# 23 23 23 bye and leg bye
# 24 24 24 fielder’s absence; substitutes
# 25 25 25 batsman’s innings
# 26 26 26 practice on the field
# 27 27 27 the wicket-keeper
# 28 28 28 the fielder
# 29 29 29 the wicket is down
# 30 30 30 batsman out of his ground
# 31 31 31 appeals
# 32 32 32 bowled
# 33 33 33 caught
# 34 34 34 hit the ball twice
# 35 35 35 hit wicket
# 36 36 36 leg before wicket
# 37 37 37 obstructing the field
# 38 38 38 run out
# 39 39 39 stumped
# 40 40 40 timed out
# 41 41 41 unfair play
# 42 42 42 players’ conduct

# %%
id2ids = dict((w, i) for i, w in enumerate(ids))

def find_section(final_str, section_id, section_title):
    try:
#         regex = "(" + section_id + "|" + str(int(section_id)+1)+ ")"  + "\s*" +section_title 
        regex = "(" + section_id + ")"  + "\s*" +section_title 
        match  = re.search(regex, final_str)
        end = match.start()
        print(1)
        
    except AttributeError:
        
        if(re.search("\.", section_id) == None):
            regex = "(" + section_title  + ")"  + "\s*" 
        else:
            regex = "(" + section_id + ")"  + "\s*"
            
        try:
            match  = re.search(regex, final_str)
            end = match.start()
            print(2)
            
        except AttributeError:
            print("error")
            return -1
        
    print(match)
    return end

for i,c in enumerate(contents):
    contents[i]  = " ".join(c.split())

# Graph Class
class Graph:

    def __init__(self,v):
        self.graph = [list() for i in range(v)]

    def addEdge(self,u,v):
        self.graph[u].append(v)

    def DFSUtil(self, v, visited,res,ans):
        visited[v]= True
        res.append(contents[v])
        #print(v)
        count=0
        for i in self.graph[v]:
            count+=1
            if visited[i] == False:
                self.DFSUtil(i, visited,res,ans)
        if count==0:
            final_res=[' '.join(res),res[-1],ind2id[v]]
            #print(final_res)
            ans.append(final_res)
        res.pop()    

    def DFS(self):
        res=[]
        ans=[]
        V = len(self.graph) 
        visited =V*[False]
        for i in range(V):
            if visited[i] == False:
                self.DFSUtil(i, visited,res,ans)
                res=[]

        return ans

id2ind = dict([(w,i) for i,w in enumerate(ids)])
ind2id = dict([(i,w) for i,w in enumerate(ids)])
nodes=[]
for it in contents:
    nodes.append(it.split())
parents=[int(i) for i in parents]
g=Graph(len(ids))
for i in ids:
    if i not in [str(i) for i in set(parents)]:
        g.addEdge(id2ind['.'.join(i.split('.')[:-1])],id2ind[i])

index_list = g.DFS()

# print(index_list)
# final_str = test_str[last:]    

start = find_section(final_str, index_list[0][2], index_list[0][1])

sections = []
for i in range(7):
    print("index", i)
    
    end = find_section(final_str, index_list[i+1][2], index_list[i+1][1])
    if(end>start):
        sections.append(final_str[start:end])
        
        for j in range(id2ids[index_list[i+1][2]]):
            regex = ids[j] + "\s+" + contents[j]
            sections[-1] = re.sub(regex, "", sections[-1])
            
        final_str = final_str[end:]
        start = 0
    else:  
        flag = 1
        print("error", i, start, end)
        
    print(start, end)
sections.append(final_str[start:])
# Out:
# 1
# <_sre.SRE_Match object; span=(5812, 5827), match='1 \n\nthe umpires'>
# index 0
# 2
# <_sre.SRE_Match object; span=(8070, 8082), match='the scorers '>
# 0 8070
# index 1
# 1
# <_sre.SRE_Match object; span=(124720, 124732), match='3 \n\nthe ball'>
# 0 124720
# index 2
# 2
# <_sre.SRE_Match object; span=(335, 342), match='the bat'>
# 0 335
# index 3
# 2
# <_sre.SRE_Match object; span=(2180, 2189), match='the pitch'>
# 0 2180
# index 4
# 2
# <_sre.SRE_Match object; span=(39798, 39812), match='the creases \n\n'>
# 0 39798
# index 5
# 2
# <_sre.SRE_Match object; span=(21371, 21388), match='the wickets \n\n \n\n'>
# 0 21371
# index 6
# error
# error 6 0 -1
# 0 -1

# %%
sections[1]
# Out:
# "the scorers of agreements in 2.3.2, 2.3.3, 2.3.4 and 2.3.6. \n\n2.4 \n\nthe wickets, creases and boundaries \n\nbefore the toss and during the match, the umpires shall satisfy themselves that \n\n2.4.1 \n\nthe wickets are properly pitched. see clause 8 (the wickets) \n\n2.4.2 \n\nthe creases are correctly marked. see clause 7 (the creases). \n\n2.4.3 \n\nthe boundary of the field of play complies with the requirements of clauses 19.1 (determining the boundary \nof the field of play), 19.2 (identifying and marking the boundary) and 19.3 (restoring the boundary). \n\n2.5 \n\nconduct of the match, implements and equipment \n\nbefore the toss and during the match, the umpires shall satisfy themselves that \n\n2.5.1 \n\nthe conduct of the match is strictly in accordance with these playing conditions. \n\n2.5.2 \n\nthe implements used in the match conform to the following \n\n2.5.2.1 \n\nclause 4 (the ball). \n\n2.5.2.2 \n\nexternally visible requirements of clause 5 (the bat) and paragraph 1 of appendix b. \n\n2.5.2.3 \n\neither clauses 8.2 (size of stumps) and 8.3 (the bails). \n\n2.5.3 \n\nno player uses equipment other than that permitted. see paragraph 2 of appendix a. note particularly \ntherein the interpretation of ‘protective helmet’. \n\n2.5.4 \n\nthe wicket-keeper’s gloves comply with the requirements of clause 27.2 (gloves). \n\n2.6 \n\nfair and unfair play \n\nthe umpires shall be the sole judges of fair and unfair play. \n\n2.7 \n\nfitness for play \n\n2.7.1 \n\nit is solely for the umpires together to decide whether either conditions of ground, weather or light or \nexceptional circumstances mean that it would be dangerous or unreasonable for play to take place. \n\n3 \n\n\x0cconditions shall not be regarded as either dangerous or unreasonable merely because they are not ideal. \n\nthe fact that the grass and the ball are wet does not warrant the ground conditions being regarded as \nunreasonable or dangerous. \n\nconditions shall be regarded as dangerous if there is actual and foreseeable risk to the safety of any player \nor umpire. \n\nconditions shall be regarded as unreasonable if, although posing no risk to safety, it would not be sensible \nfor play to proceed. \n\nif the umpires consider the ground is so wet or slippery as to deprive the bowler of a reasonable foothold, \nthe fielders of the power of free movement, or the batsmen of the ability to play their strokes or to run \nbetween the wickets, then these conditions shall be regarded as so bad that it would be dangerous and \nunreasonable for play to take place. \n\n2.7.2 \n\n2.7.3 \n\n2.7.4 \n\n2.8 \n\nsuspension of play in dangerous or unreasonable circumstances \n\n2.8.1 \n\nall references to ground include the pitch. see clause 6.1 (area of pitch). \n\n2.8.2 \n\n2.8.3 \n\nif at any time the umpires together agree that the conditions of ground, weather or light, or any other \ncircumstances are dangerous or unreasonable, they shall immediately suspend play, or not allow play to \nstart or to recommence. the decision as to whether conditions are so bad as to warrant such action is one \nfor the umpires alone to make, following consultation with the icc match referee. \n\nif circumstances are warranted, the umpires shall stop play and instruct the ground authority to take \nwhatever action they can and use whatever equipment is necessary to remove as much dew as possible \nfrom the outfield when conditions become unreasonable or dangerous. the umpires may also instruct the \nground staff to take such action during scheduled and unscheduled breaks in play. \n\n2.8.4 \n\nthe umpires shall disregard any shadow on the pitch from the stadium or from any permanent object on the \nground. \n\n2.8.5 \n\nlight meters \n\nit is the responsibility of the icc to supply light meters to the match officials to be used in accordance with \nthese playing conditions. \n\n2.8.5.1 \n\nall light meters shall be uniformly calibrated. \n\n2.8.5.2 \n\nthe umpires shall be entit ...

# %%
start
# Out:
# -1

# %%
final_str[start:start+50]
# Out:
# '1 of \nAppendix C shall be marked in white at each '

# %%
import sys
sys.path.insert(0, r'pdfminer/tools/')
import os

# %%
os.system("pdfminer/tools/dumppdf.py -T DeepLearning_Bible.pdf > Uug.txt")
# Out:
# 0

# %%
os.system("mupdf/mutool show UG-Manual.pdf outline")
# Out:
# 32512

# %%
regex = r"(Contents)|(contents)"

match = re.search(regex, test_str)
start = match.end()

contents_str = test_str[start:]

# %%
regex = r"((\s{2,})|)((\d{1,2})[\d.]*)\s+([^}].+)"
matches = re.finditer(regex, contents_str)
for matchNum, match in enumerate(matches):
    print(match.group(3), match.group(4))
# Out:
# 1 1
# 2 2
# 2.1 2
# 2.1.1 2
# 2.1.2 2
# 2.2 2
# 2.2.1 2
# 2.2.2 2
# 2.2.3 2
# 2.2.4 2
# 3 3
# 3.1 3
# 3.1.1 3
# 3.1.2 3
# 3.2 3
# 3.3 3
# 4 4
# 4.1 4
# 4.2 4
# 4.3 4
# 5 5
# 5.1 5
# 5.1.1 5
# 5.2 5
# 5.3 5
# 5.4 5
# 5.5 5
# 6 6
# 6.1 6
# 6.1.1 6
# 6.1.2 6
# 6.1.3 6
# 6.1.4 6
# 6.1.5 6
# 6.1.5.1 6
# 6.1.6 6
# 6.1.7 6
# 6.2 6
# 6.3 6
# 7 7
# 7.1 7
# 7.1.1 7
# 7.1.2 7
# 7.1.3 7
# 7.1.4 7
# 7.1.5 7
# 7.1.6 7
# 7.1.7 7
# 7.2 7
# 7.2.1 7
# 7.2.2 7
# 7.2.3 7
# 7.2.4 7
# 2 2
# 7.2.5 7
# 7.2.6 7
# 7.2.7 7
# 7.2.8 7
# 7.2.9 7
# 7.2.10 7
# 8 8
# 8.1 8
# 8.2 8
# 8.3 8
# 8.3.1 8
# 8.4 8
# 8.5 8
# 9 9
# 9.1 9
# 9.2 9
# 9.3 9
# 9.4 9
# 9.5 9
# 10 10
# 10.1 10
# 10.1.1 10
# 10.1.2 10
# 10.1.3 10
# 10.2 10
# 10.2.1 10
# 10.2.2 10
# 10.2.3 10
# 10.2.4 10
# 10.2.5 10
# 10.3 10
# 10.3.1 10
# 10.3.2 10
# 10.3.3 10
# 10.3.4 10
# 10.3.5 10
# 10.4 10
# 10.4.1 10
# 10.4.2 10
# 10.4.3 10
# 10.4.4 10
# 10.4.5 10
# 10.5 10
# 10.5.1 10
# 10.5.2 10
# 10.5.3 10
# 10.5.4 10
# 10.6 10
# 10.6.1 10
# 10.6.2 10
# 10.6.3 10
# 10.6.4 10
# 11 11
# 11.1 11
# 11.2 11
# 3 3
# 11.3 11
# 11.4 11
# 11.5 11
# 11.5.1 11
# 11.5.2 11
# 11.5.3 11
# 12 12
# 12.1 12
# 12.2 12
# 12.3 12
# 13 13
# 13.1 13
# 13.2 13
# 14 14
# 16 16
# 16.1 16
# 16.2 16
# 4 4
# 1 1
# 5 5
# 2 2
# 2.1 2
# 2.1.1 2
# 2.1.2 2
# 2.2 2
# 2.1 2
# 10. 10
# 2.2.1 2
# 2.2.2 2
# 2.2.3 2
# 6 6
# 2.2.4 2
# 7 7
# 3 3
# 3.1 3
# 3.1.1 3
# 3.1.2 3
# 8 8
# 3.2 3
# 3.3 3
# 9 9
# 4 4
# 4.1 4
# 4.2 4
# 4.3 4
# 10 10
# 5 5
# 5.1 5
# 5.1.1 5
# 5.2 5
# 5.3 5
# 11 11
# 5.4 5
# 5.5 5
# 12 12
# 6 6
# 6.1 6
# 6.1.1 6
# 6.1.2 6
# 13 13
# 6.1.3 6
# 44 44
# 6.1.4 6
# 6.1.5 6
# 30 30
# 65 65
# 6.1.5.1 6
# 30 30
# 65 65
# 100 10
# 14 14
# 8.5 8
# 70 70
# 6.1.6 6
# 25 25
# 6.1.7 6
# 20 20
# 10. 10
# 6.2 6
# 6.3 6
# 15 15
# 7 7
# 7.1 7
# 7.1.1 7
# 7.1.2 7
# 7.1.3 7
# 7.1.4 7
# 40 40
# 7.1.5 7
# 7.1.6 7
# 20 20
# 16 16
# 30 30
# 7.1.7 7
# 50 50
# 75 75
# 40 40
# 7.2 7
# 7.2.1 7
# 7.2.2 7
# 7.2.3 7
# 7.2.4 7
# 72 72
# 51 51
# 17 17
# 14 14
# 7.2.5 7
# 10 10
# 8 8
# 4 4
# 0 0
# 7.2.6 7
# 2 2
# 18 18
# 7.2.7 7
# 7.2.8 7
# 7.2.9 7
# 7.2.10 7
# 19 19
# 8 8
# 8.1 8
# 7 7
# 9 9
# 8 8
# 12 12
# 15 15
# 8.2 8
# 6.5 6
# 6.0 6
# 5.0. 5
# 1 1
# 8.3 8
# 8.1 8
# 8.3.1 8
# 8.5 8
# 20 20
# 8.4 8
# 8.3 8
# 8.5 8
# 21 21
# 9 9
# 9.1 9
# 9.2 9
# 2010 20
# 2012 20
# 2013 20
# 4.5 4
# 4.5 4
# 30 30
# 30 30
# 5.5 5
# 5.5 5
# 9.3 9
# 2010 20
# 2012 20
# 4.5 4
# 35 35
# 22 22
# 5.5 5
# 2013 20
# 30 30
# 30 30
# 30 30
# 30 30
# 9.4 9
# 2010 20
# 2012 20
# 2013 20
# 4.5 4
# 30 30
# 5.5 5
# 9.5 9
# 23 23
# 10 10
# 10.1 10
# 10.1.1 10
# 10.1.2 10
# 10.1.3 10
# 10.2 10
# 24 24
# 10.2.1 10
# 6.0 6
# 5.0 5
# 36 36
# 2011 20
# 10.6.2. 10
# 10.2.2 10
# 10.2.3 10
# 6.1.5 6
# 36 36
# 25 25
# 25 25
# 10.2.4 10
# 10.2.5 10
# 40 40
# 10.3 10
# 10.3.1 10
# 7.0 7
# 10.6.3. 10
# 10.3.2 10
# 10.3.3 10
# 26 26
# 36 36
# 25 25
# 10.3.4 10
# 10.3.5 10
# 12 12
# 12 12
# 10.4. 10
# 10.4.1 10
# 10.6.4. 10
# 10.4.2 10
# 27 27
# 10.4.3 10
# 10.4.4 10
# 36 36
# 10.4.5 10
# 10.5 10
# 10.5.1 10
# 7.0 7
# 10.5.2 10
# 10.5.3 10
# 28 28
# 6.0. 6
# 10.5.4 10
# 10.6 10
# 10.6.1 10
# 10.0 10
# 10.0 10
# 10.6.2 10
# 10 10
# 20 20
# 10 10
# 10 10
# 10 10
# 05 05
# 10.6.3 10
# 15 15
# 08 08
# 20 20
# 6 6
# 05 05
# 10 10
# 10.6.4 10
# 10 10
# 30 30
# 11 11
# 11.1 11
# 11.2 11
# 11.3 11
# 11.4 11
# 20 20
# 30 30
# 31 31
# 11.5 11
# 11.5.1 11
# 200 20
# 7.0 7
# 11.5.2 11
# 11.5.3. 11
# 11.5.3 11
# 100 10
# 32 32
# 12 12
# 12.1 12
# 12.2 12
# 12.3 12
# 33 33
# 13 13
# 13.1 13
# 13.2 13
# 34 34
# 35 35
# 14 14
# 35 35
# 25 25
# 1 1
# 2 2
# 3 3
# 4 4
# 7.0 7
# 7.0 7
# 36 36
# 5 5
# 6 6
# 6.0. 6
# 7 7
# 8 8
# 9 9
# 10 10
# 10 10
# 37 37
# 16 16
# 16.1 16
# 16.2 16
# 38 38

# %%
matches.start()
# Out:
# 18819

# %%
# retrieving indexes
regex = r"((\d{1,2})[\d.]*) ([^}].+)"
matches = re.finditer(regex, test_str)
contents = []
ids = []
parents = []
count = 0
last = None
for matchNum, match in enumerate(matches):
    matchNum = matchNum + 1

    id = match.group(1)
    if(id in ids):
        break

    count = max(count, int(match.group(2)))
    contents.append(match.group(3))
    parents.append(match.group(2))
    ids.append(id)
    last = match.end(3)
